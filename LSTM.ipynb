# %% [markdown]
# ### Bidiretional LSTM for Time Series Forecasting
#
# Libs required:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (15,4)

import numpy as np
import pandas as pd
import plotly
import plotly.graph_objs as go

from keras.preprocessing import sequence
from keras.layers import Dense, LSTM
from keras.models import Sequential
from keras.optimizers import RMSprop
from keras.metrics import mean_squared_error, mean_absolute_error
from plotly.offline import init_notebook_mode, iplot
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-0256cd149d76> in <module>
# ----> 1 get_ipython().run_line_magic('matplotlib', 'inline')
#       2 import matplotlib.pyplot as plt
#       3 plt.style.use('ggplot')
#       4 plt.rcParams['figure.figsize'] = (15,4)
#       5
#
# ~/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2305                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2306             with self.builtin_trap:
# -> 2307                 result = fn(*args, **kwargs)
#    2308             return result
#    2309
#
# </home/dieinison/.local/lib/python3.6/site-packages/decorator.py:decorator-gen-108> in matplotlib(self, line)
#
# ~/.local/lib/python3.6/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/.local/lib/python3.6/site-packages/IPython/core/magics/pylab.py in matplotlib(self, line)
#      97             print("Available matplotlib backends: %s" % backends_list)
#      98         else:
# ---> 99             gui, backend = self.shell.enable_matplotlib(args.gui.lower() if isinstance(args.gui, str) else args.gui)
#     100             self._show_matplotlib_backend(args.gui, backend)
#     101
#
# ~/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py in enable_matplotlib(self, gui)
#    3393         """
#    3394         from IPython.core import pylabtools as pt
# -> 3395         gui, backend = pt.find_gui_and_backend(gui, self.pylab_gui_select)
#    3396
#    3397         if gui != 'inline':
#
# ~/.local/lib/python3.6/site-packages/IPython/core/pylabtools.py in find_gui_and_backend(gui, gui_select)
#     274     """
#     275
# --> 276     import matplotlib
#     277
#     278     if gui and gui != 'auto':
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# #### Reading the data numerically:

# %%
features_train = pd.read_csv('./dataset/X_treino_.csv', index_col=['data'])
et0_train = pd.read_csv('./dataset/y_treino_.csv', index_col=['data'])

features_val = pd.read_csv('./dataset/X_val.csv', index_col=['data'])
et0_val = pd.read_csv('./dataset/y_val.csv', index_col=['data'])

# %%
data_train = pd.concat([features_train, et0_train], axis=1)
data_val = pd.concat([features_val, et0_val], axis=1)

# %%
BATCH_SIZE = 32
N_INPUT = len(features_train)
N_FEATURES = len(features_train.columns)

# %%
trace0 = go.Scatter(
    x = data_train.index,
    y = data_train['et0'],
    name = 'Train'
)

trace1 = go.Scatter(
    x = data_val.index,
    y = data_val['et0'],
    name = 'Validation'
)

data = [trace0, trace1]

iplot(data)
# Out:
# <div>
#
#
#             <div id="eba05e86-2476-44d2-8eb1-dc421bf44bcf" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("eba05e86-2476-44d2-8eb1-dc421bf44bcf")) {
#                     Plotly.newPlot(
#                         'eba05e86-2476-44d2-8eb1-dc421bf44bcf',
#                         [{"name": "Train", "type": "scatter", "x": ["2017-01-01", "2017-01-02", "2017-01-03", "2017-01-04", "2017-01-05", "2017-01-06", "2017-01-07", "2017-01-08", "2017-01-09", "2017-01-10", "2017-01-11", "2017-01-12", "2017-01-13", "2017-01-14", "2017-01-15", "2017-01-16", "2017-01-17", "2017-01-18", "2017-01-19", "2017-01-20", "2017-01-21", "2017-01-22", "2017-01-23", "2017-01-24", "2017-01-25", "2017-01-26", "2017-01-27", "2017-01-28", "2017-01-29", "2017-01-30", "2017-01-31", "2017-02-01", "2017-02-02", "2017-02-03", "2017-02-04", "2017-02-05", "2017-02-06", "2017-02-07", "2017-02-08", "2017-02-09", "2017-02-10", "2017-02-11", "2017-02-12", "2017-02-13", "2017-02-14", "2017-02-15", "2017-02-16", "2017-02-17", "2017-02-18", "2017-02-19", "2017-02-20", "2017-02-21", "2017-02-22", "2017-02-23", "2017-02-24", "2017-02-25", "2017-02-26", "2017-02-27", "2017-02-28", "2017-03-01", "2017-03-02", "2017-03-03", "2017-03-04", "2017-03-05", "2017-03-06", "2017-03-07", "2017-03-08", "2017-03-09", "2017-03-10", "2017-03-11", "2017-03-12", "2017-03-13", "2017-03-14", "2017-03-15", "2017-03-16", "2017-03-17", "2017-03-18", "2017-03-19", "2017-03-20", "2017-03-21", "2017-03-22", "2017-03-23", "2017-03-24", "2017-03-25", "2017-03-26", "2017-03-27", "2017-03-28", "2017-03-29", "2017-03-30", "2017-03-31", "2017-04-01", "2017-04-02", "2017-04-03", "2017-04-04", "2017-04-05", "2017-04-06", "2017-04-07", "2017-04-08", "2017-04-09", "2017-04-10", "2017-04-11", "2017-04-12", "2017-04-13", "2017-04-14", "2017-04-15", "2017-04-16", "2017-04-17", "2017-04-18", "2017-04-19", "2017-04-20", "2017-04-21", "2017-04-22", "2017-04-23", "2017-04-24", "2017-04-25", "2017-04-26", "2017-04-27", "2017-04-28", "2017-04-29", "2017-04-30", "2017-05-01", "2017-05-02", "2017-05-03", "2017-05-04", "2017-05-05", "2017-05-06", "2017-05-07", "2017-05-08", "2017-05-09", "2017-05-10", "2017-05-11", "2017-05-12", "2017-05-13", "2017-05-14", "2017-05-15", "2017-05-16", "2017-05-17", "2017-05-18", "2017-05-19", "2017-05-20", "2017-05-21", "2017-05-22", "2017-05-23", "2017-05-24", "2017-05-25", "2017-05-26", "2017-05-27", "2017-05-28", "2017-05-29", "2017-05-30", "2017-05-31", "2017-06-01", "2017-06-02", "2017-06-03", "2017-06-04", "2017-06-05", "2017-06-06", "2017-06-07", "2017-06-08", "2017-06-09", "2017-06-10", "2017-06-11", "2017-06-12", "2017-06-13", "2017-06-14", "2017-06-15", "2017-06-16", "2017-06-17", "2017-06-18", "2017-06-19", "2017-06-20", "2017-06-21", "2017-06-22", "2017-06-23", "2017-06-24", "2017-06-25", "2017-06-26", "2017-06-27", "2017-06-28", "2017-06-29", "2017-06-30", "2017-07-01", "2017-07-02", "2017-07-03", "2017-07-04", "2017-07-05", "2017-07-06", "2017-07-07", "2017-07-08", "2017-07-09", "2017-07-10", "2017-07-11", "2017-07-12", "2017-07-13", "2017-07-14", "2017-07-15", "2017-07-16", "2017-07-17", "2017-07-18", "2017-07-19", "2017-07-20", "2017-07-21", "2017-07-22", "2017-07-23", "2017-07-24", "2017-07-25", "2017-07-26", "2017-07-27", "2017-07-28", "2017-07-29", "2017-07-30", "2017-07-31", "2017-08-01"], "y": [0.058537366750000014, 0.048532031958333326, 0.06463881712500001, 0.0723622035, 0.04834153179166666, 0.052007101208333316, 0.042172067083333334, 0.056362937625000026, 0.049798368833333335, 0.04917493083333335, 0.040022481124999995, 0.06160352587499999, 0.05354226929166666, 0.054536911750000014, 0.051578466333333337, 0.04634444370833333, 0.07278042979166667, 0.051975213916666665, 0.04348887004166666, 0.027547740041666668, 0.04800123258333334, 0.05686608504166666, 0.04900698333333333, 0.06211028095833334, 0.057480437791666665, 0.06981151412500003, 0.05591724787499999, 0.04819495670833332, 0.06381066833333335, 0.06892562174999999, 0.042910464708333325, 0.048016376375, 0.06405798833333333, 0.07440809004166665, 0.08255907333333333, 0.06613952025000001, 0.07513730870833334, 0.06727125916666668, 0.051191722500000016, 0.044011193250000004, 0.041266757500000015, 0.006605759750000002, 0.021477645791666663, 0.03939103666666666, 0.02901801283 ...

# %%
def split_sequence(sequence, n_steps):
    X, y = list(), list()
    for i in range(len(sequence)):
        # find the end of this pattern
        end_ix = i + n_steps
        # check if we are beyond the sequence
        if end_ix > len(sequence)-1:
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

# %%
X, y = split_sequence(data_train['et0'].values, 5)

# %%
n_features = 1
n_steps = 5

# %%
X = X.reshape((X.shape[0], X.shape[1], n_features))

model = Sequential()
model.add((LSTM(50,
                dropout=0.2,
                recurrent_dropout=0.2,
                activation='relu',
                input_shape=(n_steps, n_features))))
model.add(Dense(1))

model.compile(optimizer='adam', 
              loss='mean_absolute_error', 
              metrics=[mean_absolute_error, mean_squared_error])

# Stacking more layers
# model.add(Bidirectional(LSTM(32, 
#                              dropout=0.2, 
#                              recurrent_dropout=0.2, 
#                              return_sequences=True))) activation='relu'

#else:
#    model.add(Bidirectional(LSTM(32, activation='relu', input_shape=(N_INPUT, N_FEATURES))))
# input_shape=(None, float_data.shape[-1]

# %%
model.fit(X, y, epochs=40, verbose=1)
# Out:
# Epoch 1/40
# 208/208 [==============================] - 0s 2ms/step - loss: 0.0176 - mean_absolute_error: 0.0176 - mean_squared_error: 5.1408e-04
# Epoch 2/40
# 208/208 [==============================] - 0s 124us/step - loss: 0.0131 - mean_absolute_error: 0.0131 - mean_squared_error: 2.5150e-04
# Epoch 3/40
# 208/208 [==============================] - 0s 89us/step - loss: 0.0117 - mean_absolute_error: 0.0117 - mean_squared_error: 2.2124e-04
# Epoch 4/40
# 208/208 [==============================] - 0s 117us/step - loss: 0.0112 - mean_absolute_error: 0.0112 - mean_squared_error: 2.0757e-04
# Epoch 5/40
# 208/208 [==============================] - 0s 100us/step - loss: 0.0108 - mean_absolute_error: 0.0108 - mean_squared_error: 1.9390e-04
# Epoch 6/40
# 208/208 [==============================] - 0s 109us/step - loss: 0.0110 - mean_absolute_error: 0.0110 - mean_squared_error: 2.0431e-04
# Epoch 7/40
# 208/208 [==============================] - 0s 114us/step - loss: 0.0113 - mean_absolute_error: 0.0113 - mean_squared_error: 2.1787e-04
# Epoch 8/40
# 208/208 [==============================] - 0s 142us/step - loss: 0.0111 - mean_absolute_error: 0.0111 - mean_squared_error: 2.1761e-04
# Epoch 9/40
# 208/208 [==============================] - 0s 130us/step - loss: 0.0108 - mean_absolute_error: 0.0108 - mean_squared_error: 2.0280e-04
# Epoch 10/40
# 208/208 [==============================] - 0s 100us/step - loss: 0.0110 - mean_absolute_error: 0.0110 - mean_squared_error: 2.1195e-04
# Epoch 11/40
# 208/208 [==============================] - 0s 108us/step - loss: 0.0110 - mean_absolute_error: 0.0110 - mean_squared_error: 2.0542e-04
# Epoch 12/40
# 208/208 [==============================] - 0s 124us/step - loss: 0.0109 - mean_absolute_error: 0.0109 - mean_squared_error: 2.2178e-04
# Epoch 13/40
# 208/208 [==============================] - 0s 108us/step - loss: 0.0103 - mean_absolute_error: 0.0103 - mean_squared_error: 1.8511e-04
# Epoch 14/40
# 208/208 [==============================] - 0s 113us/step - loss: 0.0104 - mean_absolute_error: 0.0104 - mean_squared_error: 1.9995e-04
# Epoch 15/40
# 208/208 [==============================] - 0s 113us/step - loss: 0.0105 - mean_absolute_error: 0.0105 - mean_squared_error: 1.8549e-04
# Epoch 16/40
# 208/208 [==============================] - 0s 136us/step - loss: 0.0099 - mean_absolute_error: 0.0099 - mean_squared_error: 1.7881e-04
# Epoch 17/40
# 208/208 [==============================] - 0s 112us/step - loss: 0.0110 - mean_absolute_error: 0.0110 - mean_squared_error: 2.1300e-04
# Epoch 18/40
# 208/208 [==============================] - 0s 119us/step - loss: 0.0104 - mean_absolute_error: 0.0104 - mean_squared_error: 2.0833e-04
# Epoch 19/40
# 208/208 [==============================] - 0s 123us/step - loss: 0.0105 - mean_absolute_error: 0.0105 - mean_squared_error: 2.0089e-04
# Epoch 20/40
# 208/208 [==============================] - 0s 106us/step - loss: 0.0097 - mean_absolute_error: 0.0097 - mean_squared_error: 1.6967e-04
# Epoch 21/40
# 208/208 [==============================] - 0s 132us/step - loss: 0.0103 - mean_absolute_error: 0.0103 - mean_squared_error: 1.8334e-04
# Epoch 22/40
# 208/208 [==============================] - 0s 107us/step - loss: 0.0104 - mean_absolute_error: 0.0104 - mean_squared_error: 1.8890e-04
# Epoch 23/40
# 208/208 [==============================] - 0s 123us/step - loss: 0.0103 - mean_absolute_error: 0.0103 - mean_squared_error: 2.0705e-04
# Epoch 24/40
# 208/208 [==============================] - 0s 111us/step - loss: 0.0098 - mean_absolute_error: 0.0098 - mean_squared_error: 1.6807e-04
# Epoch 25/40
# 208/208 [==============================] - 0s 127us/step - loss: 0.0103 - mean_absolute_error: 0.0103 - mean_squared_error: 1.7963e-04
# Epoch 26/40
# 208/208 [==============================] - 0s 128us/step - loss: 0.0109 - mean_absolute_error: 0.0109 - mean_squared_error: 2.2351e-04
# Epoch 27/40
# 208/208 [==============================] - 0s 104us/step - loss: 0.0110 - mean_absolute_error: 0.0110 - mean_squared_error: 1.9658e-04
# Epoch 28/40
# 208/208 [==============================] - 0s 132us/step - loss: 0.0103 - mean_absolute_error: 0.0103 - mean_squared_error: 2.0243e-04
# Epoch 29/40
# 208/208 [==============================] - 0s 122us/step - loss: 0.0105 - mean_absolute_error: 0.0105 - mean_squared_error: 1.9090e-04
# Epoch 30/40
# 208/208 [==============================] - 0s 109us/step - loss: 0.0104 - mean_absolute_error: 0.0104 - mean_squared_error: 2.0844e-04
# Epoch 31/40
# 208/208 [==============================] - 0s 135us/step - loss: 0.0095 - mean_absolute_error: 0.0095 - mean_squared_error: 1.4848e-04
# Epoch 32/40
# 208/208 [==============================] - 0s 120us/step - loss: 0.0098 - mean_absolute_error: 0.0098 - mean_squared_error: 1.7135e-04
# Epoch 33/40
# 208/208 [==============================] - 0s 115us/step - loss: 0.0097 - mean_absolute_error: 0.0097 - mean_squared_error: 1.5820e-04
# Epoch 34/40
# 208/208 [==============================] - 0s 134us/step - loss: 0.0101 - mean_absolute_error: 0.0101 - mean_squared_error: 1.7065e-04
# Epoch 35/40
# 208/208 [==============================] - 0s 133us/step - loss: 0.0097 - mean_absolute_error: 0.0097 - mean_squared_error: 1.7883e-04
# Epoch 36/40
# 208/208 [==============================] - 0s 127us/step - loss: 0.0100 - mean_absolute_error: 0.0100 - mean_squared_error: 1.7146e-04
# Epoch 37/40
# 208/208 [==============================] - 0s 136us/step - loss: 0.0100 - mean_absolute_error: 0.0100 - mean_squared_error: 1.6476e-04
# Epoch 38/40
# 208/208 [==============================] - 0s 222us/step - loss: 0.0094 - mean_absolute_error: 0.0094 - mean_squared_error: 1.7247e-04
# Epoch 39/40
# 208/208 [==============================] - 0s 134us/step - loss: 0.0099 - mean_absolute_error: 0.0099 - mean_squared_error: 1.7047e-04
# Epoch 40/40
# 208/208 [==============================] - 0s 112us/step - loss: 0.0101 - mean_absolute_error: 0.0101 - mean_squared_error: 1.9068e-04

# %%
X_val, y_val = split_sequence(data_val['et0'].values, 5)

# %%
X_val = X_val.reshape((X_val.shape[0], X_val.shape[1], n_features))

# %%
y_pred = model.predict(X_val, verbose=1)
# Out:
# 49/49 [==============================] - 0s 1ms/step

# %%
y_pred = np.array([val for sublist in y_pred for val in sublist])

# %%
mae = mean_absolute_error(y_val, y_pred)
mae
# Out:
# <tf.Tensor: id=4287, shape=(), dtype=float32, numpy=0.01611248>

# %%
mse = mean_squared_error(y_val, y_pred)

# %%
plt.figure(figsize=(12,5))  
plt.plot(y_val, color='blue', label='ET0 true')  
plt.plot(y_pred, color='red', label='ET0 predicted')  
plt.title('ET0 Forecasting')  
plt.xlabel('Date')  
plt.ylabel('ET0')  
plt.legend()
#plt.savefig("eto.png")
plt.show()

# %% [markdown]
# There are many other things you could try, in order to improve performance on the temperature-forecasting problem:
# - Adjust the number of units in each recurrent layer in the stacked setup. The current choices are largely arbitrary and thus probably suboptimal.
# - Adjust the learning rate used by the RMSprop optimizer. Change the optimizer to Adam.
# - Try using LSTM layers instead of GRU layers (vice-versa).
# - Try using a bigger densely connected regressor on top of the recurrent layers: that is, a bigger Dense layer or even a stack of Dense layers.
# - Don’t forget to eventually run the best-performing models (in terms of validation MAE ) on the test set! Otherwise, you’ll develop architectures that are overfitting to the validation set.

# %%
model.save('./saved_models/lstm_50units_40epochs.h5')

# %%
model.evaluate_generator(test_gen,steps=test_steps)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-c4646233fa72> in <module>
# ----> 1 model.evaluate_generator(test_gen,steps=test_steps)
#
# NameError: name 'test_gen' is not defined

# %%
np.sqrt(4.1739006723676413)
# Out:
# 2.0430126461594997

# %% [markdown]
# * MAE  = 1.6325380717005049
#
# * RMSE = 2.0430126461594997
